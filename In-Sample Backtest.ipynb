# %%
# Importieren der benötigten Bibliotheken bzw. Module, müssen ggf. vorher mit pip installiert werden
import os
import pandas as pd
import matplotlib.pyplot as plt
import pandas_ta as ta
import numpy as np
import math

# Funktion, um Datensatz in einen Dataframe zu laden und Zeitraum zu beschränken
def load_csv_to_dataframe(file_path, start_date, end_date):
    df = pd.read_csv(file_path, parse_dates=True, index_col='date')
    df.index = pd.to_datetime(df.index, errors='coerce')
    df.dropna(inplace=True)
    
    # Zeitraum wird beschränkt
    df = df.loc[start_date:end_date]
    return df

# Verzeichnis des benutzten Datensatz, ggf. muss die "tickers.csv" Datei vorher aus dem Zielordner entfernt werden.
data_dir = "C:\\Users\\Moritz\\Desktop\\bereinigte SP500 Data\\survivorship-free-spy-master\\survivorship-free\\Datenlul"

# Liste der Aktienticker bzw. der Dateinamen 
tickers = [f.replace('.csv', '') for f in os.listdir(data_dir) if f.endswith('.csv')]

# Zeitraum wird festgelegt auf den In-Sample-Zeitraum
start_date = "2013-02-28"
end_date = "2015-02-27"

# Funktion, die die ganzen Indikatoren hinzufügt
def add_indicators(df):
    df['200_EMA'] = df['close'].ewm(span=200, adjust=False).mean()
    df['RSI'] = ta.rsi(df['close'], length=14)
    df['BB_middle'] = df['close'].rolling(window=20).mean()
    df['BB_std'] = df['close'].rolling(window=20).std()
    df['BB_upper'] = df['BB_middle'] + (df['BB_std'] * 2)
    df['BB_lower'] = df['BB_middle'] - (df['BB_std'] * 2)
    df['BB_bandwidth'] = df['BB_upper'] - df['BB_lower']
    short_vol = df['volume'].ewm(span=10, adjust=False).mean()
    long_vol = df['volume'].ewm(span=20, adjust=False).mean()
    df['Volume_Oscillator'] = 100 * (short_vol - long_vol) / long_vol
    return df

# Klasse, in der die Funktionsweise der Mean-Reversion-Strategie steht
class TradingStrategy:
    # Initialisierung
    def __init__(self, df, ticker, initial_capital=70000, risk_per_trade=200, stop_loss_percent=3, take_profit_percent=3, verbose=False):
        self.df = df  # Dataframe, der die Aktiendaten enthält
        self.ticker = ticker  # Ticker der Aktien
        self.initial_capital = initial_capital  # Startkapital
        self.risk_per_trade = risk_per_trade  # Risiko pro Trade
        self.stop_loss_percent = stop_loss_percent  # Stop-Loss %
        self.take_profit_percent = take_profit_percent # Take-Profit %, wurde vor allem beim Entwicklung für Tests benutzt
        self.verbose = verbose  # Optional
        self.position = None  # Aktuelle Position vom Trade
        self.entry_price = None  # Einstiegspreis
        self.stop_loss = None  # Stop-Loss Preis
        self.take_profit = None # Take-Profit Preis
        self.capital = initial_capital # Verfügbares Kapital
        self.total_profit = 0  # Gesamter Gewinn bzw. Verlust aus allen Trades
        self.trades = []  # Liste aller abgeschlossenen Trades
        self.trade_durations = []  # Liste der Dauer jedes Trades
        self.trade_entries = []  # Liste der Einstiegszeitpunkte
        self.trade_exits = []  # Liste der Ausstiegszeitpunkte
        self.stop_losses = []  # Liste der Stop-Losses
        self.exit_signals = []  # Liste von Daten bei Erfüllung vom Ausstiegssignals
        self.transaction_cost_fixed = 2  # Direkte Transaktionskosten
        self.transaction_cost_percent = 0.0005  # Indirekte Transaktionskosten
    # Funktion zur Anwendung der Strategie
    def apply_strategy(self):
        entry_date = None

        for i in range(len(self.df) - 1):  # Iteration
            row = self.df.iloc[i]  # Aktuelle Zeile im DataFrame
            next_row = self.df.iloc[i + 1]  # Nächste Zeile im DataFrame
            
            if self.position is None:
                # Einstiegssignal
                if row['close'] < row['BB_lower'] and row['RSI'] < 30 and row['close'] > row['200_EMA'] and row['Volume_Oscillator'] > 0:
                    self.position = 'long'  # Long-Position
                    self.entry_price = next_row['open']  # Verwendung des Open-Preis des nächsten Tages, wegen Lookahead-Bias
                    self.stop_loss = self.entry_price * (1 - self.stop_loss_percent / 100)
                    self.take_profit = self.entry_price * (1 + self.take_profit_percent / 100)
                    position_size = math.floor(self.risk_per_trade / (self.entry_price - self.stop_loss))  # Positionsgröße auf ganze Zahl abrunden
                    entry_date = self.df.index[i + 1]
                    self.trade_entries.append((entry_date, self.ticker, self.entry_price, position_size))  # Speichern vom Einstiegsdatum + Details
                    self.stop_losses.append(self.stop_loss)  # Speichern vom Stop-Loss
                    if self.verbose:
                        print(f"Long-Trade am {entry_date} bei {self.entry_price} mit Positionsgröße von {position_size}")

            elif self.position == 'long':
                # Ausstiegssignal
                if row['close'] > row['BB_middle'] or row['close'] <= self.stop_loss:
                    self.exit_signals.append(self.df.index[i])  # Speichern des Datums
                    exit_price = next_row['open']  # Verwendung vom Open-Preis des nächsten Tages, wegen Lookahead-Bias
                    profit = (exit_price - self.entry_price) * position_size
                    # Transaktionskosten berechnen
                    transaction_costs = (self.transaction_cost_fixed + (self.entry_price * self.transaction_cost_percent * position_size)) + \
                                        (self.transaction_cost_fixed + (exit_price * self.transaction_cost_percent * position_size))
                    profit -= transaction_costs
                    self.total_profit += profit
                    self.capital += profit  # Anpassung laufendes Kapital
                    self.trades.append(profit)
                    # Berechnung der Dauer des Trades, sowohl der Ein- als auch der Ausstiegstag werden mitgezählt
                    duration = (self.df.index[i + 1] - entry_date).days + 1
                    self.trade_durations.append(duration)
                    self.trade_exits.append((self.df.index[i + 1], exit_price, profit, transaction_costs, duration))  # Speichern vom Ausstiegsdatum + Details
                    if self.verbose:
                        print(f"Long-Trade Ausstieg am {self.df.index[i + 1]} bei {exit_price} mit Gewinn von {profit} nach Transaktionskosten von {transaction_costs}")
                    self.position = None

        if self.verbose:
            print(f"Total Profit: {self.total_profit}")
            print(f"Ending Capital: {self.capital}")

    # Funktion zur Berechnung der Kennzahlen
    def calculate_metrics(self):
        total_return = (self.capital - self.initial_capital) / self.initial_capital * 100

        # Annualisierte Rendite
        num_days = (self.df.index[-1] - self.df.index[0]).days
        if num_days > 0:
            annualized_return = ((self.capital / self.initial_capital) ** (365.0 / num_days) - 1) * 100
        else:
            annualized_return = 0

        # Berechnung der täglichen Renditen
        self.df['daily_return'] = self.df['close'].pct_change()
        daily_returns = self.df['daily_return'].dropna()

        # Durchschnittliche tägliche Rendite auf Basis der annualisierten Rendite
        avg_daily_return = ((1 + annualized_return / 100) ** (1 / 252) - 1) * 100

        # Berechnung der Standardabweichung der täglichen Renditen
        std_daily_return = daily_returns.std() * 100

        metrics = {
            'Startkapital ($)': self.initial_capital,
            'Endkapital ($)': self.capital,
            'Gesamtrendite (%)': total_return,
            'Annualisierte Rendite (%)': annualized_return,
            'Durchschnittliche tägliche Rendite (%)': avg_daily_return,
            'Standardabweichung der täglichen Renditen (%)': std_daily_return,
            'trade_entries': self.trade_entries,
            'trade_exits': self.trade_exits,
            'trades': self.trades
        }

        return metrics

# Funktion die Strategie auf alle Daten anwendet
def analyze_all_tickers(data_dir, tickers, start_date, end_date):
    initial_capital = 70000
    total_profit_all_tickers = 0
    combined_trades = []
    combined_trade_dates = []
    combined_trade_durations = []
    trade_details = []
    results = []
    combined_capital = initial_capital

    for ticker in tickers:
        file_path = os.path.join(data_dir, f"{ticker}.csv")

        df = load_csv_to_dataframe(file_path, start_date, end_date)

        # Überprüfung, ob DataFrame leer ist
        if df.empty:
            print(f"DataFrame for ticker {ticker} is empty after filtering. Skipping this ticker.")
            continue

        # Hinzufügen von Indikatoren
        df = add_indicators(df)

        # Zeilen mit NaN-Werten in den Indikatoren entfernen
        df.dropna(inplace=True)
        
        # Überprüfen, ob der DataFrame nach dem Entfernen der NaN-Werte leer ist
        if df.empty:
            print(f"Dataframe für Aktie {ticker} ist leer nach Entfernen von NaNs. Wird Übersprungen.")
            continue

        # Strategie anwenden
        strategy = TradingStrategy(df, ticker, initial_capital=combined_capital, risk_per_trade=200, verbose=False)
        strategy.apply_strategy()

        # Erfassung von Gewinn und Trades für den aktuellen Ticker
        metrics = strategy.calculate_metrics()
        results.append((ticker, metrics))
        combined_trades.extend(strategy.trades)
        combined_trade_dates.extend(strategy.trade_entries)
        combined_trade_durations.extend(strategy.trade_durations)
        for entry, exit in zip(strategy.trade_entries, strategy.trade_exits):
            trade_details.append({
                'Ticker': ticker,
                'Entry Date': entry[0],
                'Entry Price': entry[2],
                'Position Size': entry[3],
                'Exit Date': exit[0],
                'Exit Price': exit[1],
                'Profit': exit[2],
                'Transaction Costs': exit[3],
                'Duration': exit[4]
            })

    # Sortierung der Trades nach Datum
    trade_details_sorted = sorted(trade_details, key=lambda x: x['Entry Date'])
    sorted_trades_and_dates = sorted(zip(combined_trade_dates, combined_trades), key=lambda x: x[0])
    sorted_trades = [trade for _, trade in sorted_trades_and_dates]

    # Berechnung weiterer Kennzahlen
    num_trades = len(combined_trades)
    num_winning_trades = len([t for t in combined_trades if t > 0])
    num_losing_trades = len([t for t in combined_trades if t < 0])
    avg_win = np.mean([t for t in combined_trades if t > 0]) if num_winning_trades > 0 else 0
    avg_loss = np.mean([t for t in combined_trades if t < 0]) if num_losing_trades > 0 else 0
    avg_duration = np.mean(combined_trade_durations) if combined_trade_durations else 0

    if len(combined_trades) == 0:
        print("Es konnten keine Trades durchgeführt werden. Kennzahlen können nicht berechnet werden.")
        return results, {}, []

    combined_capital = initial_capital + sum(sorted_trades)
    total_return = (combined_capital - initial_capital) / initial_capital * 100

    # Annualisierte Rendite
    num_days = (pd.to_datetime(end_date) - pd.to_datetime(start_date)).days
    if num_days > 0:
        annualized_return = ((combined_capital / initial_capital) ** (365.0 / num_days) - 1) * 100
    else:
        annualized_return = 0

    # Kumuliertes Kapital
    cumulative_capital = [initial_capital] + list(initial_capital + np.cumsum(sorted_trades))

    # Berechnung der täglichen Renditen zum kumulierte Kapital
    cumulative_capital_series = pd.Series(cumulative_capital)
    cumulative_capital_daily_returns = cumulative_capital_series.pct_change().dropna()

    # Durchschnittliche tägliche Rendite auf Basis der annualisierten Rendite
    avg_daily_return_combined = ((1 + annualized_return / 100) ** (1 / 252) - 1) * 100

    # Berechnung der Standardabweichung der täglichen Renditen
    std_daily_return_combined = cumulative_capital_daily_returns.std() * 100

    if num_trades > 1:
        avg_daily_return = np.mean(combined_trades) / initial_capital
        std_daily_return = np.std(combined_trades) / initial_capital
        sharpe_ratio = (avg_daily_return / std_daily_return) * np.sqrt(252) if std_daily_return != 0 else 0
    else:
        sharpe_ratio = 0

    # Drawdown
    if len(sorted_trades) > 0:
        cumulative_returns = np.cumsum(sorted_trades)
        drawdowns = cumulative_returns - np.maximum.accumulate(cumulative_returns)
        max_drawdown = np.min(drawdowns)
        max_drawdown_percentage = max_drawdown / np.maximum.accumulate(cumulative_returns).max() * 100 if len(cumulative_returns) > 0 else 0
    else:
        max_drawdown_percentage = 0

    profit_to_drawdown_ratio = annualized_return / abs(max_drawdown_percentage) if max_drawdown_percentage != 0 else 0

    combined_metrics = {
        'Startkapital ($)': initial_capital,
        'Endkapital ($)': combined_capital,
        'Gesamtrendite (%)': total_return,
        'Annualisierte Rendite (%)': annualized_return,
        'Durchschnittliche tägliche Rendite (%)': avg_daily_return_combined,
        'Standardabweichung der täglichen Renditen (%)': std_daily_return_combined,
        'Anzahl ausgeführter Trades': num_trades,
        'Anzahl erfolgreicher Trades': num_winning_trades,
        'Anzahl erfolgloser Trades': num_losing_trades,
        'Gewinnrate (%)': (num_winning_trades / num_trades * 100) if num_trades > 0 else 0,
        'Durchschnittliche Dauer eines Trades (Tage)': avg_duration,
        'Sharpe-Ratio': sharpe_ratio,
        'Maximum Drawdown (%)': max_drawdown_percentage,
        'Rendite-Drawdown-Verhältnis': profit_to_drawdown_ratio,
        'Average Win ($)': avg_win,
        'Average Loss ($)': avg_loss
    }

    return results, combined_metrics, sorted_trades, trade_details_sorted

# Plotten der Strategie Ergebnisse + Ausgabe Kennzahlen im Graph
def plot_strategy_results(results, combined_metrics, sorted_trades):
    fig, ax = plt.subplots(figsize=(14, 7))
    
    # Kumuliertes Kapital berechnen
    cumulative_capital = [70000] + list(70000 + np.cumsum(sorted_trades))
    ax.plot(cumulative_capital, label="Kumuliertes Kapital")
    
    # Annotieren der Kennzahlen, mit 2 Kommastellen
    textstr = '\n'.join((
        f"Startkapital ($): {combined_metrics['Startkapital ($)']:.2f}",
        f"Endkapital ($): {combined_metrics['Endkapital ($)']:.2f}",
        f"Gesamtrendite (%): {combined_metrics['Gesamtrendite (%)']:.2f}",
        f"Annualisierte Rendite (%): {combined_metrics['Annualisierte Rendite (%)']:.2f}",
        f"Durchschnittliche tägliche Rendite (%): {combined_metrics['Durchschnittliche tägliche Rendite (%)']:.2f}",
        f"Standardabweichung der täglichen Renditen (%): {combined_metrics['Standardabweichung der täglichen Renditen (%)']:.2f}",
        f"Anzahl ausgeführter Trades: {combined_metrics['Anzahl ausgeführter Trades']}",
        f"Anzahl erfolgreicher Trades: {combined_metrics['Anzahl erfolgreicher Trades']}",
        f"Anzahl erfolgloser Trades: {combined_metrics['Anzahl erfolgloser Trades']}",
        f"Gewinnrate (%): {combined_metrics['Gewinnrate (%)']:.2f}",
        f"Durchschnittliche Dauer eines Trades (Tage): {combined_metrics['Durchschnittliche Dauer eines Trades (Tage)']:.2f}",
        f"Sharpe-Ratio: {combined_metrics['Sharpe-Ratio']:.2f}",
        f"Maximum Drawdown (%): {combined_metrics['Maximum Drawdown (%)']:.2f}",
        f"Rendite-Drawdown-Verhältnis: {combined_metrics['Rendite-Drawdown-Verhältnis']:.2f}",
        f"Average Win ($): {combined_metrics['Average Win ($)']:.2f}",
        f"Average Loss ($): {combined_metrics['Average Loss ($)']:.2f}"
    ))

    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=12,
            verticalalignment='top', bbox=props)

    ax.set_title("Strategie kumulatives Kapital und Leistungskennzahlen")
    ax.set_xlabel("Trades")
    ax.set_ylabel("Kumulatives Kapital ($)")
    ax.legend()
    plt.show()
    
    # Ergebnisse anzeigen
    for ticker, metrics in results:
        print(f"Ergebnisse für {ticker}:")
        for key, value in metrics.items():
            print(f"{key}: {value}")
        print("\n")

    print("Kombinierte Kennzahlen für alle Ticker:")
    for key, value in combined_metrics.items():
        print(f"{key}: {value}")

    print(f"Endkapital für alle Ticker: {combined_metrics['Endkapital ($)']}")

# Funktion zur Generierung eines .csv bzw. Excel-Dokuments
def save_trades_to_csv(trade_details, file_path):
    df = pd.DataFrame(trade_details)
    df.to_csv(file_path, index=False)

# Anwendung der Funktionen
results, combined_metrics, sorted_trades, trade_details_sorted = analyze_all_tickers(data_dir, tickers, start_date, end_date)
plot_strategy_results(results, combined_metrics, sorted_trades)

# Optional: Generierung .csv Dokument mit allen Trade-Details auf Desktop
#########save_trades_to_csv(trade_details_sorted, "Trades_Details_InSample.csv")
# Out:
# DataFrame for ticker AA is empty after filtering. Skipping this ticker.
# DataFrame for ticker AAL is empty after filtering. Skipping this ticker.
# DataFrame for ticker AAP is empty after filtering. Skipping this ticker.
# DataFrame for ticker AJG is empty after filtering. Skipping this ticker.
# DataFrame for ticker ALB is empty after filtering. Skipping this ticker.
# DataFrame for ticker ALGN is empty after filtering. Skipping this ticker.
# DataFrame for ticker ALK is empty after filtering. Skipping this ticker.
# DataFrame for ticker ANDV is empty after filtering. Skipping this ticker.
# DataFrame for ticker ANSS is empty after filtering. Skipping this ticker.
# DataFrame for ticker AOS is empty after filtering. Skipping this ticker.
# DataFrame for ticker APTV is empty after filtering. Skipping this ticker.
# DataFrame for ticker ARE is empty after filtering. Skipping this ticker.
# DataFrame for ticker ARNC is empty after filtering. Skipping this ticker.
# DataFrame for ticker ATVI is empty after filtering. Skipping this ticker.
# DataFrame for ticker AWK is empty after filtering. Skipping this ticker.
# DataFrame for ticker AYI is empty after filtering. Skipping this ticker.
# DataFrame for ticker BF_B is empty after filtering. Skipping this ticker.
# DataFrame for ticker BHF is empty after filtering. Skipping this ticker.
# DataFrame for ticker BHGE is empty after filtering. Skipping this ticker.
# DataFrame for ticker BLD is empty after filtering. Skipping this ticker.
# DataFrame for ticker BTI is empty after filtering. Skipping this ticker.
# DataFrame for ticker BXLT is empty after filtering. Skipping this ticker.
# DataFrame for ticker CBOE is empty after filtering. Skipping this ticker.
# DataFrame for ticker CC is empty after filtering. Skipping this ticker.
# DataFrame for ticker CDNS is empty after filtering. Skipping this ticker.
# DataFrame for ticker CFG is empty after filtering. Skipping this ticker.
# DataFrame for ticker CHD is empty after filtering. Skipping this ticker.
# DataFrame for ticker CHTR is empty after filtering. Skipping this ticker.
# DataFrame for ticker CMCSK is empty after filtering. Skipping this ticker.
# DataFrame for ticker CNC is empty after filtering. Skipping this ticker.
# DataFrame for ticker COO is empty after filtering. Skipping this ticker.
# DataFrame for ticker COTY is empty after filtering. Skipping this ticker.
# DataFrame for ticker CPGX is empty after filtering. Skipping this ticker.
# DataFrame for ticker CSRA is empty after filtering. Skipping this ticker.
# DataFrame for ticker CXO is empty after filtering. Skipping this ticker.
# DataFrame for ticker DISH is empty after filtering. Skipping this ticker.
# DataFrame for ticker DLR is empty after filtering. Skipping this ticker.
# DataFrame for ticker DRE is empty after filtering. Skipping this ticker.
# DataFrame for ticker DWDP is empty after filtering. Skipping this ticker.
# DataFrame for ticker DXC is empty after filtering. Skipping this ticker.
# DataFrame for ticker EQIX is empty after filtering. Skipping this ticker.
# DataFrame for ticker EVHC is empty after filtering. Skipping this ticker.
# DataFrame for ticker EXR is empty after filtering. Skipping this ticker.
# DataFrame for ticker FBHS is empty after filtering. Skipping this ticker.
# DataFrame for ticker FL is empty after filtering. Skipping this ticker.
# DataFrame for ticker FOX is empty after filtering. Skipping this ticker.
# DataFrame for ticker FRT is empty after filtering. Skipping this ticker.
# DataFrame for ticker FTV is empty after filtering. Skipping this ticker.
# DataFrame for ticker GPN is empty after filtering. Skipping this ticker.
# DataFrame for ticker HBI is empty after filtering. Skipping this ticker.
# DataFrame for ticker HII is empty after filtering. Skipping this ticker.
# DataFrame for ticker HLT is empty after filtering. Skipping this ticker.
# DataFrame for ticker HOLX is empty after filtering. Skipping this ticker.
# DataFrame for ticker HPE is empty after filtering. Skipping this ticker.
# DataFrame for ticker HSIC is empty after filtering. Skipping this ticker.
# DataFrame for ticker IDXX is empty after filtering. Skipping this ticker.
# DataFrame for ticker ILMN is empty after filtering. Skipping this ticker.
# DataFrame for ticker INCY is empty after filtering. Skipping this ticker.
# DataFrame for ticker INFO is empty after filtering. Skipping this ticker.
# DataFrame for ticker IQV is empty after filtering. Skipping this ticker.
# DataFrame for ticker IT is empty after filtering. Skipping this ticker.
# DataFrame for ticker JBHT is empty after filtering. Skipping this ticker.
# DataFrame for ticker KHC is empty after filtering. Skipping this ticker.
# DataFrame for ticker LIFE is empty after filtering. Skipping this ticker.
# DataFrame for ticker LKQ is empty after filtering. Skipping this ticker.
# DataFrame for ticker LNT is empty after filtering. Skipping this ticker.
# Dataframe für Aktie LPRAX ist leer nach Entfernen von NaNs. Wird Übersprungen.
# DataFrame for ticker MAA is empty after filtering. Skipping this ticker.
# DataFrame for ticker MGM is empty after filtering. Skipping this ticker.
# DataFrame for ticker MTD is empty after filtering. Skipping this ticker.
# DataFrame for ticker NCLH is empty after filtering. Skipping this ticker.
# DataFrame for ticker NWS is empty after filtering. Skipping this ticker.
# DataFrame for ticker O is empty after filtering. Skipping this ticker.
# DataFrame for ticker PKG is empty after filtering. Skipping this ticker.
# DataFrame for ticker PYPL is empty after filtering. Skipping this ticker.
# DataFrame for ticker Q is empty after filtering. Skipping this ticker.
# DataFrame for ticker QRVO is empty after filtering. Skipping this ticker.
# DataFrame for ticker RE is empty after filtering. Skipping this ticker.
# DataFrame for ticker REG is empty after filtering. Skipping this ticker.
# DataFrame for ticker RJF is empty after filtering. Skipping this ticker.
# DataFrame for ticker RMD is empty after filtering. Skipping this ticker.
# DataFrame for ticker SBAC is empty after filtering. Skipping this ticker.
# DataFrame for ticker SIG is empty after filtering. Skipping this ticker.
# DataFrame for ticker SLG is empty after filtering. Skipping this ticker.
# DataFrame for ticker SNPS is empty after filtering. Skipping this ticker.
# DataFrame for ticker SPGI is empty after filtering. Skipping this ticker.
# DataFrame for ticker SWKS is empty after filtering. Skipping this ticker.
# DataFrame for ticker SYF is empty after filtering. Skipping this ticker.
# DataFrame for ticker TDG is empty after filtering. Skipping this ticker.
# DataFrame for ticker TPR is empty after filtering. Skipping this ticker.
# DataFrame for ticker UA is empty after filtering. Skipping this ticker.
# DataFrame for ticker UAA is empty after filtering. Skipping this ticker.
# DataFrame for ticker UAL is empty after filtering. Skipping this ticker.
# DataFrame for ticker UDR is empty after filtering. Skipping this ticker.
# DataFrame for ticker ULTA is empty after filtering. Skipping this ticker.
# DataFrame for ticker VRSK is empty after filtering. Skipping this ticker.
# DataFrame for ticker WLTW is empty after filtering. Skipping this ticker.
# DataFrame for ticker WRK is empty after filtering. Skipping this ticker.
# Ergebnisse für A:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.5765888579986085
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AABA:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.948067938452315
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AAPL:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.34555272683705
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ABBV:
# Startkapital ($): 70000
# Endkapital ($): 70224.89582606163
# Gesamtrendite (%): 0.3212797515166208
# Annualisierte Rendite (%): 0.16691854744850243
# Durchschnittliche tägliche Rendite (%): 0.0006618251792156471
# Standardabweichung der täglichen Renditen (%): 1.6231286428818472
# trade_entries: [(Timestamp('2014-01-28 00:00:00'), 'ABBV', 41.264334303034, 161)]
# trade_exits: [(Timestamp('2014-02-10 00:00:00'), 42.728043697386, 224.89582606163842, 10.76138642903381, 14)]
# trades: [224.89582606163842]
#
#
# Ergebnisse für ABC:
# Startkapital ($): 70000
# Endkapital ($): 69704.59039792433
# Gesamtrendite (%): -0.4220137172509567
# Annualisierte Rendite (%): -0.2196458158863046
# Durchschnittliche tägliche Rendite (%): -0.0008725652054786259
# Standardabweichung der täglichen Renditen (%): 0.9688057047123588
# trade_entries: [(Timestamp('2014-01-27 00:00:00'), 'ABC', 63.17691265694899, 105), (Timestamp('2014-03-24 00:00:00'), 'ABC', 61.740731189416, 107)]
# trade_exits: [(Timestamp('2014-02-05 00:00:00'), 61.08483708865501, -230.1916765325127, 10.523741861644211, 10), (Timestamp('2014-04-17 00:00:00'), 61.23008645297401, -65.21792554316147, 10.578938743867866, 25)]
# trades: [-230.1916765325127, -65.21792554316147]
#
#
# Ergebnisse für ABT:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.128926832295879
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ACE:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.0933914944062706
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ACN:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.174858926163763
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ADBE:
# Startkapital ($): 70000
# Endkapital ($): 69566.820645
# Gesamtrendite (%): -0.6188276500000003
# Annualisierte Rendite (%): -0.32223450492513406
# Durchschnittliche tägliche Rendite (%): -0.0012807648073320799
# Standardabweichung der täglichen Renditen (%): 1.6297769287452568
# trade_entries: [(Timestamp('2014-09-18 00:00:00'), 'ADBE', 67.28, 99)]
# trade_exits: [(Timestamp('2014-10-13 00:00:00'), 63.01, -433.1793550000003, 10.449355, 26)]
# trades: [-433.1793550000003]
#
#
# Ergebnisse für ADI:
# Startkapital ($): 70000
# Endkapital ($): 69762.702490914
# Gesamtrendite (%): -0.338996441551426
# Annualisierte Rendite (%): -0.1764024936421693
# Durchschnittliche tägliche Rendite (%): -0.0007006255855257493
# Standardabweichung der täglichen Renditen (%): 1.2553660549960544
# trade_entries: [(Timestamp('2014-07-24 00:00:00'), 'ADI', 47.198315247711, 141)]
# trade_exits: [(Timestamp('2014-08-01 00:00:00'), 45.590117200914, -237.29750908600502, 10.541584487628063, 9)]
# trades: [-237.29750908600502]
#
#
# Ergebnisse für ADM:
# Startkapital ($): 70000
# Endkapital ($): 69676.66161247491
# Gesamtrendite (%): -0.4619119821786964
# Annualisierte Rendite (%): -0.6845909006295559
# Durchschnittliche tägliche Rendite (%): -0.0027259349653085962
# Standardabweichung der täglichen Renditen (%): 1.4493800211760892
# trade_entries: [(Timestamp('2014-10-10 00:00:00'), 'ADM', 42.99536116366, 155)]
# trade_exits: [(Timestamp('2014-10-14 00:00:00'), 40.977099732656, -323.3383875250844, 10.50786571946449, 5)]
# trades: [-323.3383875250844]
#
#
# Ergebnisse für ADP:
# Startkapital ($): 70000
# Endkapital ($): 69852.89887122608
# Gesamtrendite (%): -0.21014446967703407
# Annualisierte Rendite (%): -0.1093183204551762
# Durchschnittliche tägliche Rendite (%): -0.00043403920294560194
# Standardabweichung der täglichen Renditen (%): 0.9059954756896228
# trade_entries: [(Timestamp('2014-02-04 00:00:00'), 'ADP', 62.722303565253, 106)]
# trade_exits: [(Timestamp('2014-02-05 00:00:00'), 61.43437125385199, -147.10112877391938, 10.580303765412564, 2)]
# trades: [-147.10112877391938]
#
#
# Ergebnisse für ADS:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.7135686726554085
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ADSK:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.7214642170441643
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ADT:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.8464387897093488
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AEC:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.5212051420467843
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AEE:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.1277078545881452
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AEP:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.0555971840217087
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AES:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.4167819411627325
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AET:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.383861895270578
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AFL:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 0.9589629753204286
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AGN:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.5709707016818633
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AIG:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.0781631732408616
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AIV:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.1456702115366515
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AIZ:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.0899886817399427
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AKAM:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 2.049336971146081
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ALD:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 0.3645067645082301
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ALL:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 0.9418045177634082
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ALLE:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.392430896958305
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ALTR:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.4485086916855625
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ALXN:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 2.492495104304128
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AMAT:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.6103402899242836
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AMD:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 3.5878079740755546
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AME:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.1778376132372348
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AMG:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.5558731896904732
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AMGN:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.6528162040985486
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AMP:
# Startkapital ($): 70000
# Endkapital ($): 69747.01320138521
# Gesamtrendite (%): -0.36140971230683916
# Annualisierte Rendite (%): -0.18807576003736504
# Durchschnittliche tägliche Rendite (%): -0.0007470323071800955
# Standardabweichung der täglichen Renditen (%): 1.3572626798174745
# trade_entries: [(Timestamp('2014-01-28 00:00:00'), 'AMP', 95.966585011541, 69)]
# trade_exits: [(Timestamp('2014-02-04 00:00:00'), 92.452290121357, -252.98679861478126, 10.50045119208498, 8)]
# trades: [-252.98679861478126]
#
#
# Ergebnisse für AMT:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.1664174940303464
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AMZN:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.9524524983217475
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AN:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.545434894787781
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ANF:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 2.4743043859877885
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ANTM:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.3406735103489642
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AON:
# Startkapital ($): 70000
# Endkapital ($): 69769.2858576171
# Gesamtrendite (%): -0.32959163197557373
# Annualisierte Rendite (%): -0.17150466165563039
# Durchschnittliche tägliche Rendite (%): -0.0006811560105624004
# Standardabweichung der täglichen Renditen (%): 1.1193309744829958
# trade_entries: [(Timestamp('2014-07-29 00:00:00'), 'AON', 83.870502480297, 79)]
# trade_exits: [(Timestamp('2014-08-01 00:00:00'), 81.083180050893, -230.714142382898, 10.515670459982006, 4)]
# trades: [-230.714142382898]
#
#
# Ergebnisse für APA:
# Startkapital ($): 70000
# Endkapital ($): 70126.93228224313
# Gesamtrendite (%): 0.1813318317758967
# Annualisierte Rendite (%): 0.09424122074204178
# Durchschnittliche tägliche Rendite (%): 0.00037379768902390254
# Standardabweichung der täglichen Renditen (%): 1.6730459376681446
# trade_entries: [(Timestamp('2013-12-13 00:00:00'), 'APA', 80.88673862006256, 82)]
# trade_exits: [(Timestamp('2014-01-08 00:00:00'), 82.56519973854836, 126.9322822431325, 10.701529472703047, 27)]
# trades: [126.9322822431325]
#
#
# Ergebnisse für APC:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 2.055946228301157
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für APD:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.3065978326019752
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für APH:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.2245501649884643
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für APOL:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 2.686978217163986
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ARG:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.0494348610311353
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ATI:
# Startkapital ($): 70000
# Endkapital ($): 70401.37049830357
# Gesamtrendite (%): 0.5733864261479591
# Annualisierte Rendite (%): 0.2977191154008185
# Durchschnittliche tägliche Rendite (%): 0.0011796768379479516
# Standardabweichung der täglichen Renditen (%): 2.1154246518647044
# trade_entries: [(Timestamp('2014-07-31 00:00:00'), 'ATI', 36.51414020790131, 182)]
# trade_exits: [(Timestamp('2014-08-14 00:00:00'), 38.77909725687313, 401.370498303576, 10.851684609294473, 15)]
# trades: [401.370498303576]
#
#
# Ergebnisse für AVB:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.0523770930869127
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AVGO:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 2.41913304177461
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AVP:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 2.145277427320952
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AVY:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.244185620868131
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AXP:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.2149167040168962
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für AZO:
# Startkapital ($): 70000
# Endkapital ($): 70229.097215
# Gesamtrendite (%): 0.327281735714288
# Annualisierte Rendite (%): 0.17003439078657756
# Durchschnittliche tägliche Rendite (%): 0.0006741689231981596
# Standardabweichung der täglichen Renditen (%): 1.0786265807854638
# trade_entries: [(Timestamp('2014-07-23 00:00:00'), 'AZO', 510.22, 13)]
# trade_exits: [(Timestamp('2014-08-11 00:00:00'), 528.67, 229.09721499999912, 10.752785, 20)]
# trades: [229.09721499999912]
#
#
# Ergebnisse für BA:
# Startkapital ($): 70000
# Endkapital ($): 70466.47929602406
# Gesamtrendite (%): 0.6663989943200846
# Annualisierte Rendite (%): 0.34593709382433335
# Durchschnittliche tägliche Rendite (%): 0.0013704066434083728
# Standardabweichung der täglichen Renditen (%): 1.2962052396575976
# trade_entries: [(Timestamp('2014-01-31 00:00:00'), 'BA', 111.56975158783, 59), (Timestamp('2014-06-26 00:00:00'), 'BA', 115.50821784234, 57)]
# trade_exits: [(Timestamp('2014-02-19 00:00:00'), 117.29909116224, 327.27940402906324, 10.751630861127065, 20), (Timestamp('2014-07-15 00:00:00'), 118.1373194179, 139.19989199500318, 10.658897811916841, 20)]
# trades: [327.27940402906324, 139.19989199500318]
#
#
# Ergebnisse für BAC:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.4134306155086203
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für BAX:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.002771531237991
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für BBBY:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.3741556080670765
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für BBT:
# Startkapital ($): 70000
# Endkapital ($): 69814.54582729837
# Gesamtrendite (%): -0.2649345324309044
# Annualisierte Rendite (%): -0.13783857386526766
# Durchschnittliche tägliche Rendite (%): -0.0005473542901590633
# Standardabweichung der täglichen Renditen (%): 1.0410607810690224
# trade_entries: [(Timestamp('2014-07-22 00:00:00'), 'BBT', 33.788316990984, 197)]
# trade_exits: [(Timestamp('2014-08-08 00:00:00'), 32.900574265538, -185.45417270163003, 10.568855788767417, 18)]
# trades: [-185.45417270163003]
#
#
# Ergebnisse für BBY:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 2.780354638735999
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für BCR:
# Startkapital ($): 70000
# Endkapital ($): 70345.58867089976
# Gesamtrendite (%): 0.49369810128536684
# Annualisierte Rendite (%): 0.2563914327960992
# Durchschnittliche tägliche Rendite (%): 0.0010161294113464336
# Standardabweichung der täglichen Renditen (%): 1.0854736611884697
# trade_entries: [(Timestamp('2014-02-04 00:00:00'), 'BCR', 123.93897258019, 53)]
# trade_exits: [(Timestamp('2014-02-11 00:00:00'), 130.6622858679, 345.5886708997563, 10.746933348874386, 8)]
# trades: [345.5886708997563]
#
#
# Ergebnisse für BDX:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 0.997151635072791
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für BEAM:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.7469884339968216
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für BEN:
# Startkapital ($): 70000
# Endkapital ($): 70203.96975436599
# Gesamtrendite (%): 0.2913853633799798
# Annualisierte Rendite (%): 0.15139797491321438
# Durchschnittliche tägliche Rendite (%): 0.0006003330865977929
# Standardabweichung der täglichen Renditen (%): 1.364031672562871
# trade_entries: [(Timestamp('2014-08-01 00:00:00'), 'BEN', 50.707330603083, 131)]
# trade_exits: [(Timestamp('2014-08-20 00:00:00'), 52.34641285165, 203.96975436599197, 10.75002019628501, 20)]
# trades: [203.96975436599197]
#
#
# Ergebnisse für BHI:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.7352006784082128
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für BIIB:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 2.2714848737221778
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für BK:
# Startkapital ($): 70000
# Endkapital ($): 70475.24034072043
# Gesamtrendite (%): 0.6789147724577509
# Annualisierte Rendite (%): 0.35242367575625266
# Durchschnittliche tägliche Rendite (%): 0.001396057835023612
# Standardabweichung der täglichen Renditen (%): 1.2118504965371488
# trade_entries: [(Timestamp('2014-10-16 00:00:00'), 'BK', 33.308256707367, 200)]
# trade_exits: [(Timestamp('2014-10-28 00:00:00'), 35.738982030338, 475.2403407204295, 10.9047238737705, 13)]
# trades: [475.2403407204295]
#
#
# Ergebnisse für BLK:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.3835053186447832
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für BLL:
# Startkapital ($): 70000
# Endkapital ($): 70296.06401130435
# Gesamtrendite (%): 0.42294858757764037
# Annualisierte Rendite (%): 0.21968637938021285
# Durchschnittliche tägliche Rendite (%): 0.0008708189570327818
# Standardabweichung der täglichen Renditen (%): 1.1773444983715156
# trade_entries: [(Timestamp('2014-01-27 00:00:00'), 'BLL', 23.641251802, 281)]
# trade_exits: [(Timestamp('2014-01-31 00:00:00'), 24.733282525763, 296.06401130435205, 10.7966220730507, 5)]
# trades: [296.06401130435205]
#
#
# Ergebnisse für BMS:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 0.9509172535185033
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für BMY:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.4457391455084159
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für BRCM:
# Startkapital ($): 70000
# Endkapital ($): 70680.69229892004
# Gesamtrendite (%): 0.9724175698857704
# Annualisierte Rendite (%): 0.5044272410796857
# Durchschnittliche tägliche Rendite (%): 0.0019966836996676562
# Standardabweichung der täglichen Renditen (%): 1.5901569388289973
# trade_entries: [(Timestamp('2014-10-13 00:00:00'), 'BRCM', 35.468779792037495, 187)]
# trade_exits: [(Timestamp('2014-10-23 00:00:00'), 39.1675541029424, 680.692298920036, 10.97849721918062, 11)]
# trades: [680.692298920036]
#
#
# Ergebnisse für BRK_B:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 0.8966321555525569
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für BSX:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.7875278193134805
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für BTU:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 2.0968846623610737
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für BWA:
# Startkapital ($): 70000
# Endkapital ($): 70274.75717214966
# Gesamtrendite (%): 0.39251024592809175
# Annualisierte Rendite (%): 0.20389106006231117
# Durchschnittliche tägliche Rendite (%): 0.000808271061503163
# Standardabweichung der täglichen Renditen (%): 1.5427388858729063
# trade_entries: [(Timestamp('2014-08-01 00:00:00'), 'BWA', 58.860891201065, 113)]
# trade_exits: [(Timestamp('2014-08-21 00:00:00'), 61.38789322292, 274.75717214965954, 10.794056319955153, 21)]
# trades: [274.75717214965954]
#
#
# Ergebnisse für BXP:
# Startkapital ($): 70000
# Endkapital ($): 70115.75061943811
# Gesamtrendite (%): 0.16535802776873296
# Annualisierte Rendite (%): 0.08594265541896906
# Durchschnittliche tägliche Rendite (%): 0.0003408963979767421
# Standardabweichung der täglichen Renditen (%): 1.1064944851595981
# trade_entries: [(Timestamp('2014-09-16 00:00:00'), 'BXP', 106.20729602749, 62)]
# trade_exits: [(Timestamp('2014-10-06 00:00:00'), 108.24598427148, 115.75061943811161, 10.64805168926807, 21)]
# trades: [115.75061943811161]
#
#
# Ergebnisse für C:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.3622868886802217
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CA:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.15423670207654
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CAG:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.1728950413200407
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CAH:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.181335567231927
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CAM:
# Startkapital ($): 70000
# Endkapital ($): 69703.503
# Gesamtrendite (%): -0.42356714285714714
# Annualisierte Rendite (%): -0.22045515315585185
# Durchschnittliche tägliche Rendite (%): -0.0008757839160211667
# Standardabweichung der täglichen Renditen (%): 1.7950750239840187
# trade_entries: [(Timestamp('2014-10-01 00:00:00'), 'CAM', 66.4, 100)]
# trade_exits: [(Timestamp('2014-10-03 00:00:00'), 63.54, -296.4970000000007, 10.497, 3)]
# trades: [-296.4970000000007]
#
#
# Ergebnisse für CAT:
# Startkapital ($): 70000
# Endkapital ($): 70004.89067614485
# Gesamtrendite (%): 0.006986680206921716
# Annualisierte Rendite (%): 0.0036326146882093013
# Durchschnittliche tägliche Rendite (%): 1.441487686992815e-05
# Standardabweichung der täglichen Renditen (%): 1.2662672116898446
# trade_entries: [(Timestamp('2014-08-01 00:00:00'), 'CAT', 89.65075449249399, 74), (Timestamp('2014-09-22 00:00:00'), 'CAT', 91.059908811019, 73)]
# trade_exits: [(Timestamp('2014-08-13 00:00:00'), 93.048778513747, 240.69389485149165, 10.759882721230916, 13), (Timestamp('2014-10-01 00:00:00'), 87.974039227413, -235.8032187066406, 10.534739103402767, 10)]
# trades: [240.69389485149165, -235.8032187066406]
#
#
# Ergebnisse für CB:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 0.8362206516109522
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CBG:
# Startkapital ($): 70000
# Endkapital ($): 70276.080195
# Gesamtrendite (%): 0.39440027857143184
# Annualisierte Rendite (%): 0.20487191857909703
# Durchschnittliche tägliche Rendite (%): 0.0008121554497808603
# Standardabweichung der täglichen Renditen (%): 1.3851007158223239
# trade_entries: [(Timestamp('2014-08-07 00:00:00'), 'CBG', 30.44, 219)]
# trade_exits: [(Timestamp('2014-08-20 00:00:00'), 31.75, 276.0801949999997, 10.809805, 14)]
# trades: [276.0801949999997]
#
#
# Ergebnisse für CBS:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.463421632109759
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CCE:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.1786982900250624
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CCI:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.1933353265359743
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CCL:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.3790517969906617
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CELG:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.8561358821766856
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CERN:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.38615241992335
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CF:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.6177595355899868
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CFN:
# Startkapital ($): 70000
# Endkapital ($): 70227.92442
# Gesamtrendite (%): 0.3256063142857082
# Annualisierte Rendite (%): 0.1691646289732951
# Durchschnittliche tägliche Rendite (%): 0.0006707233079605857
# Standardabweichung der täglichen Renditen (%): 1.473780164872918
# trade_entries: [(Timestamp('2014-08-08 00:00:00'), 'CFN', 42.54, 156)]
# trade_exits: [(Timestamp('2014-08-14 00:00:00'), 44.07, 227.92442000000017, 10.75558, 7)]
# trades: [227.92442000000017]
#
#
# Ergebnisse für CHK:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 2.318645980529645
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CHRW:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.3353787238070622
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CI:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.4080704013366865
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CINF:
# Startkapital ($): 70000
# Endkapital ($): 69702.17118002239
# Gesamtrendite (%): -0.4254697428251633
# Annualisierte Rendite (%): -0.22144641909426221
# Durchschnittliche tägliche Rendite (%): -0.0008797261869752937
# Standardabweichung der täglichen Renditen (%): 0.9014190855011383
# trade_entries: [(Timestamp('2014-01-27 00:00:00'), 'CINF', 42.899840556227005, 155)]
# trade_exits: [(Timestamp('2014-02-06 00:00:00'), 41.046143742069, -297.82881997760893, 10.50581378311794, 11)]
# trades: [-297.82881997760893]
#
#
# Ergebnisse für CL:
# Startkapital ($): 70000
# Endkapital ($): 70001.65009726743
# Gesamtrendite (%): 0.0023572818106081935
# Annualisierte Rendite (%): 0.0012256452886383329
# Durchschnittliche tägliche Rendite (%): 4.863642089070197e-06
# Standardabweichung der täglichen Renditen (%): 0.9391728185083196
# trade_entries: [(Timestamp('2014-07-31 00:00:00'), 'CL', 60.22143487082501, 110)]
# trade_exits: [(Timestamp('2014-08-26 00:00:00'), 60.333076647197, 1.6500972674276309, 10.63049813349121, 27)]
# trades: [1.6500972674276309]
#
#
# Ergebnisse für CLF:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 3.1948077823467833
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CLX:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 0.9282851439323442
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CMA:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.3387076235064057
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CMCSA:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.21958276211248
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CME:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.130626643807413
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CMG:
# Startkapital ($): 70000
# Endkapital ($): 70741.273295
# Gesamtrendite (%): 1.058961850000009
# Annualisierte Rendite (%): 0.5492075660990636
# Durchschnittliche tägliche Rendite (%): 0.0021734558437902507
# Standardabweichung der täglichen Renditen (%): 1.8416123823707724
# trade_entries: [(Timestamp('2014-01-27 00:00:00'), 'CMG', 492.36, 13)]
# trade_exits: [(Timestamp('2014-02-03 00:00:00'), 550.21, 741.2732950000003, 10.776705000000002, 8)]
# trades: [741.2732950000003]
#
#
# Ergebnisse für CMI:
# Startkapital ($): 70000
# Endkapital ($): 69763.3356098677
# Gesamtrendite (%): -0.3380919859032812
# Annualisierte Rendite (%): -0.17593146204317733
# Durchschnittliche tägliche Rendite (%): -0.000698753126937568
# Standardabweichung der täglichen Renditen (%): 1.4474790793374452
# trade_entries: [(Timestamp('2014-07-30 00:00:00'), 'CMI', 131.2590551025, 50)]
# trade_exits: [(Timestamp('2014-08-01 00:00:00'), 126.73476420951, -236.66439013230072, 10.44984548280025, 3)]
# trades: [-236.66439013230072]
#
#
# Ergebnisse für CMS:
# Startkapital ($): 70000
# Endkapital ($): 70285.51952967301
# Gesamtrendite (%): 0.4078850423900128
# Annualisierte Rendite (%): 0.21186976558345005
# Durchschnittliche tägliche Rendite (%): 0.000839867170165931
# Standardabweichung der täglichen Renditen (%): 1.0225163907022117
# trade_entries: [(Timestamp('2014-08-06 00:00:00'), 'CMS', 25.561116230191, 260)]
# trade_exits: [(Timestamp('2014-08-15 00:00:00'), 26.700783832811, 285.5195296730091, 10.79404700819026, 10)]
# trades: [285.5195296730091]
#
#
# Ergebnisse für CNP:
# Startkapital ($): 70000
# Endkapital ($): 70035.71992845478
# Gesamtrendite (%): 0.05102846922111764
# Annualisierte Rendite (%): 0.026528647505097425
# Durchschnittliche tägliche Rendite (%): 0.00010525850493436906
# Standardabweichung der täglichen Renditen (%): 1.1359006772351565
# trade_entries: [(Timestamp('2013-08-20 00:00:00'), 'CNP', 19.050142104988, 349)]
# trade_exits: [(Timestamp('2013-09-11 00:00:00'), 19.183069393989, 35.719928454777374, 10.671695406571487, 23)]
# trades: [35.719928454777374]
#
#
# Ergebnisse für CNX:
# Startkapital ($): 70000
# Endkapital ($): 69669.73010662892
# Gesamtrendite (%): -0.47181413338725436
# Annualisierte Rendite (%): -0.24559493197851
# Durchschnittliche tägliche Rendite (%): -0.0009757770290552692
# Standardabweichung der täglichen Renditen (%): 1.8771988125774994
# trade_entries: [(Timestamp('2014-07-18 00:00:00'), 'CNX', 40.59992107309424, 164)]
# trade_exits: [(Timestamp('2014-08-01 00:00:00'), 38.65009551205095, -330.2698933710804, 10.498501359981905, 15)]
# trades: [-330.2698933710804]
#
#
# Ergebnisse für COF:
# Startkapital ($): 70000
# Endkapital ($): 70097.8405502504
# Gesamtrendite (%): 0.1397722146434327
# Annualisierte Rendite (%): 0.07264922269425433
# Durchschnittliche tägliche Rendite (%): 0.00028818631176985576
# Standardabweichung der täglichen Renditen (%): 1.1495309699351488
# trade_entries: [(Timestamp('2014-01-28 00:00:00'), 'COF', 65.090966717249, 102)]
# trade_exits: [(Timestamp('2014-02-13 00:00:00'), 66.155026481009, 97.8405502504088, 10.693545653111158, 17)]
# trades: [97.8405502504088]
#
#
# Ergebnisse für COG:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.8760273157162122
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für COH:
# Startkapital ($): 70000
# Endkapital ($): 70060.67012899648
# Gesamtrendite (%): 0.08667161285211998
# Annualisierte Rendite (%): 0.045054929114085596
# Durchschnittliche tägliche Rendite (%): 0.00017874929638672654
# Standardabweichung der täglichen Renditen (%): 1.6051534918234565
# trade_entries: [(Timestamp('2013-07-31 00:00:00'), 'COH', 45.481042681286, 146)]
# trade_exits: [(Timestamp('2013-09-04 00:00:00'), 45.969714148718005, 60.67012899648259, 10.675905248590293, 36)]
# trades: [60.67012899648259]
#
#
# Ergebnisse für COL:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 0.9948803840370964
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für COP:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.1578795966703523
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für COST:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 0.9378343530917814
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für COV:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.5688012149390897
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für CPB:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.1405106272822085
# ...
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.2372462832795963
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für VAR:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.2142707716312635
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für VFC:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.1463769660194687
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für VIAB:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.2883429172921317
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für VLO:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.9099950715656784
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für VMC:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.6997897589659723
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für VNO:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.0121320225343566
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für VRSN:
# Startkapital ($): 70000
# Endkapital ($): 69660.71399999999
# Gesamtrendite (%): -0.4846942857142962
# Annualisierte Rendite (%): -0.25230730738118323
# Durchschnittliche tägliche Rendite (%): -0.0010024796524010782
# Standardabweichung der täglichen Renditen (%): 1.2889369775500341
# trade_entries: [(Timestamp('2014-02-06 00:00:00'), 'VRSN', 55.42, 120)]
# trade_exits: [(Timestamp('2014-02-10 00:00:00'), 52.68, -339.28600000000023, 10.486, 5)]
# trades: [-339.28600000000023]
#
#
# Ergebnisse für VRTX:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 3.1975430188624374
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für VTR:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.2492470956324775
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für VZ:
# Startkapital ($): 70000
# Endkapital ($): 70285.58969226618
# Gesamtrendite (%): 0.40798527466596823
# Annualisierte Rendite (%): 0.2119217789047223
# Durchschnittliche tägliche Rendite (%): 0.0008400731375424186
# Standardabweichung der täglichen Renditen (%): 1.023627577728329
# trade_entries: [(Timestamp('2013-06-03 00:00:00'), 'VZ', 40.00916065617768, 166)]
# trade_exits: [(Timestamp('2013-06-14 00:00:00'), 41.79457874434889, 285.58969226617756, 10.789710370243705, 12)]
# trades: [285.58969226617756]
#
#
# Ergebnisse für WAG:
# Startkapital ($): 70000
# Endkapital ($): 70554.22406989489
# Gesamtrendite (%): 0.7917486712784116
# Annualisierte Rendite (%): 0.44867108267534483
# Durchschnittliche tägliche Rendite (%): 0.0017764743289072626
# Standardabweichung der täglichen Renditen (%): 1.6430233319127006
# trade_entries: [(Timestamp('2013-06-28 00:00:00'), 'WAG', 44.366914050252674, 150)]
# trade_exits: [(Timestamp('2013-07-11 00:00:00'), 48.134658635894965, 554.2240698948825, 10.937617951461073, 14)]
# trades: [554.2240698948825]
#
#
# Ergebnisse für WAT:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.315761299525742
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für WBA:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.3373423079390365
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für WDC:
# Startkapital ($): 70000
# Endkapital ($): 69736.22318765373
# Gesamtrendite (%): -0.376824017637534
# Annualisierte Rendite (%): -0.1961045609892742
# Durchschnittliche tägliche Rendite (%): -0.0007789537032065752
# Standardabweichung der täglichen Renditen (%): 1.634761213229273
# trade_entries: [(Timestamp('2015-01-28 00:00:00'), 'WDC', 96.12702386345, 69)]
# trade_exits: [(Timestamp('2015-01-29 00:00:00'), 92.456434254157, -263.7768123462747, 10.506129305057442, 2)]
# trades: [-263.7768123462747]
#
#
# Ergebnisse für WEC:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.0596120805858447
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für WFC:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 0.9647822101957455
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für WFM:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.822876712515133
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für WHR:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.8571120884628745
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für WIN:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.5734611904107905
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für WLP:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.3419530567942286
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für WM:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 0.8888994381064658
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für WMB:
# Startkapital ($): 70000
# Endkapital ($): 69684.33671177452
# Gesamtrendite (%): -0.45094755460782576
# Annualisierte Rendite (%): -0.23472138730715741
# Durchschnittliche tägliche Rendite (%): -0.0009325245796443227
# Standardabweichung der täglichen Renditen (%): 1.6663592551229969
# trade_entries: [(Timestamp('2014-10-10 00:00:00'), 'WMB', 41.882282073251, 159)]
# trade_exits: [(Timestamp('2014-10-14 00:00:00'), 39.963058276599, -315.6632882254808, 10.506704557813077, 5)]
# trades: [-315.6632882254808]
#
#
# Ergebnisse für WMT:
# Startkapital ($): 70000
# Endkapital ($): 69978.55693419403
# Gesamtrendite (%): -0.030632951151388366
# Annualisierte Rendite (%): -0.015928560414479875
# Durchschnittliche tägliche Rendite (%): -6.32135877309814e-05
# Standardabweichung der täglichen Renditen (%): 0.8538690695341905
# trade_entries: [(Timestamp('2013-08-16 00:00:00'), 'WMT', 66.6226959463, 100)]
# trade_exits: [(Timestamp('2013-09-11 00:00:00'), 66.51483405324001, -21.44306580597602, 10.656876499977, 27)]
# trades: [-21.44306580597602]
#
#
# Ergebnisse für WPG:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 2.444478370342339
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für WPX:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 2.215594393491419
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für WU:
# Startkapital ($): 70000
# Endkapital ($): 69785.64294433419
# Gesamtrendite (%): -0.3062243652368696
# Annualisierte Rendite (%): -0.1593364286056942
# Durchschnittliche tägliche Rendite (%): -0.0006327896807989397
# Standardabweichung der täglichen Renditen (%): 1.3918971435626075
# trade_entries: [(Timestamp('2013-10-31 00:00:00'), 'WU', 14.929997436575, 446)]
# trade_exits: [(Timestamp('2013-11-21 00:00:00'), 14.473046367298, -214.3570556658058, 10.55687876826368, 22)]
# trades: [-214.3570556658058]
#
#
# Ergebnisse für WY:
# Startkapital ($): 70000
# Endkapital ($): 70079.57459802707
# Gesamtrendite (%): 0.11367799718153297
# Annualisierte Rendite (%): 0.05908996253372045
# Durchschnittliche tägliche Rendite (%): 0.00023441500209830934
# Standardabweichung der täglichen Renditen (%): 1.2077526445903046
# trade_entries: [(Timestamp('2014-09-23 00:00:00'), 'WY', 28.247808539108, 236)]
# trade_exits: [(Timestamp('2014-10-15 00:00:00'), 28.630377284677, 79.57459802707724, 10.71162592720663, 23)]
# trades: [79.57459802707724]
#
#
# Ergebnisse für WYN:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.3293155531262117
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für WYNN:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.9071429526375128
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für X:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 4.426942485880707
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für XEC:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 2.7215039067481044
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für XEL:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 0.9923422915676527
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für XL:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.0052121838242598
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für XLNX:
# Startkapital ($): 70000
# Endkapital ($): 69732.63497398171
# Gesamtrendite (%): -0.3819500371689875
# Annualisierte Rendite (%): -0.19877466686472056
# Durchschnittliche tägliche Rendite (%): -0.0007895702395899207
# Standardabweichung der täglichen Renditen (%): 1.5641437575905786
# trade_entries: [(Timestamp('2014-04-25 00:00:00'), 'XLNX', 43.41966134615, 153)]
# trade_exits: [(Timestamp('2014-05-07 00:00:00'), 41.740901588282, -267.3650260182882, 10.51478306448405, 13)]
# trades: [-267.3650260182882]
#
#
# Ergebnisse für XOM:
# Startkapital ($): 70000
# Endkapital ($): 70191.1709764232
# Gesamtrendite (%): 0.27310139489027535
# Annualisierte Rendite (%): 0.1419042070675003
# Durchschnittliche tägliche Rendite (%): 0.0005627143538466939
# Standardabweichung der täglichen Renditen (%): 1.00029950391489
# trade_entries: [(Timestamp('2014-02-03 00:00:00'), 'XOM', 80.381857460869, 82)]
# trade_exits: [(Timestamp('2014-02-18 00:00:00'), 82.843604050444, 191.17097642318618, 10.692243921963833, 16)]
# trades: [191.17097642318618]
#
#
# Ergebnisse für XRAY:
# Startkapital ($): 70000
# Endkapital ($): 69868.64219695824
# Gesamtrendite (%): -0.18765400434536528
# Annualisierte Rendite (%): -0.09761337796188041
# Durchschnittliche tägliche Rendite (%): -0.00038754310160982186
# Standardabweichung der täglichen Renditen (%): 0.9784607966753367
# trade_entries: [(Timestamp('2014-01-27 00:00:00'), 'XRAY', 42.92086013335, 155)]
# trade_exits: [(Timestamp('2014-02-18 00:00:00'), 42.141728182077, -131.35780304175967, 10.592350594445591, 23)]
# trades: [-131.35780304175967]
#
#
# Ergebnisse für XRX:
# Startkapital ($): 70000
# Endkapital ($): 69766.90305300262
# Gesamtrendite (%): -0.33299563856768405
# Annualisierte Rendite (%): -0.17327737287212708
# Durchschnittliche tägliche Rendite (%): -0.0006882026785448581
# Standardabweichung der täglichen Renditen (%): 1.6035190174957064
# trade_entries: [(Timestamp('2014-01-28 00:00:00'), 'XRX', 39.199788715166, 170)]
# trade_exits: [(Timestamp('2014-02-04 00:00:00'), 37.89070486197, -233.09694699737662, 10.552691954056561, 8)]
# trades: [-233.09694699737662]
#
#
# Ergebnisse für XYL:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.593808087589008
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für YHOO:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.775933206030207
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für YUM:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.3716786193109287
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ZBH:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.227293234270416
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ZION:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.4651142061767464
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ZMH:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.3158155470137827
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Ergebnisse für ZTS:
# Startkapital ($): 70000
# Endkapital ($): 70000
# Gesamtrendite (%): 0.0
# Annualisierte Rendite (%): 0.0
# Durchschnittliche tägliche Rendite (%): 0.0
# Standardabweichung der täglichen Renditen (%): 1.274774581864549
# trade_entries: []
# trade_exits: []
# trades: []
#
#
# Kombinierte Kennzahlen für alle Ticker:
# Startkapital ($): 70000
# Endkapital ($): 78795.62659472415
# Gesamtrendite (%): 12.565180849605925
# Annualisierte Rendite (%): 6.1053526906748035
# Durchschnittliche tägliche Rendite (%): 0.023519554241846485
# Standardabweichung der täglichen Renditen (%): 0.4193544813268781
# Anzahl ausgeführter Trades: 185
# Anzahl erfolgreicher Trades: 106
# Anzahl erfolgloser Trades: 79
# Gewinnrate (%): 57.2972972972973
# Durchschnittliche Dauer eines Trades (Tage): 13.05945945945946
# Sharpe-Ratio: 2.401261506797807
# Maximum Drawdown (%): -28.7031793362961
# Rendite-Drawdown-Verhältnis: 0.2127064956513158
# Average Win ($): 277.9097912857916
# Average Loss ($): -261.55457318442734
# Endkapital für alle Ticker: 78795.62659472415

# %%
# Nochmal eine Funktion zum Graphen, aber ohne Trade Details
def plot_cumulative_capital(combined_trades):
    fig, ax = plt.subplots(figsize=(14, 7))

    cumulative_capital = 70000 + np.cumsum(combined_trades)
    ax.plot(cumulative_capital, label="Kumuliertes Kapital")

    ax.set_title("Ergebnisse In-Sample Backtest")
    ax.set_xlabel("Anzahl der Trades")
    ax.set_ylabel("kumuliertes Kapital in $")
    ax.legend()
    plt.show()
    

plot_cumulative_capital(sorted_trades)
